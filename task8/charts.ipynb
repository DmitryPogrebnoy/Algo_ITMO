# %%
import os.path as osp

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('task8.csv')
df
# Out:
#    algo  main_n  n_edges      time
# 0    fw      55    110.0  0.531120
# 1    fw      55    165.0  0.541114
# 2    fw      55    220.0  0.529134
# 3    fw      50    100.0  0.403778
# 4    fw      50    150.0  0.396932
# 5    fw      50    200.0  0.398261
# 6    fw      45     90.0  0.289304
# 7    fw      45    135.0  0.290390
# 8    fw      45    180.0  0.288055
# 9    fw      40     80.0  0.203189
# 10   fw      40    120.0  0.206332
# 11   fw      40    160.0  0.203058
# 12   fw      35     70.0  0.135449
# 13   fw      35    105.0  0.138151
# 14   fw      35    140.0  0.135734
# 15   fw      30     60.0  0.084603
# 16   fw      30     90.0  0.086153
# 17   fw      30    120.0  0.087070
# 18   fw      25     50.0  0.059574
# 19   fw      25     75.0  0.048997
# 20   fw      25    100.0  0.050118
# 21   fw      20     40.0  0.025451
# 22   fw      20     60.0  0.026312
# 23   fw      20     80.0  0.026556
# 24   fw      15     30.0  0.011115
# 25   fw      15     45.0  0.011100
# 26   fw      15     60.0  0.010829
# 27   fw      10     20.0  0.003301
# 28   fw      10     30.0  0.003311
# 29   fw      10     40.0  0.003293
# 30   mc     100      NaN  1.789343
# 31   mc      95      NaN  1.522913
# 32   mc      90      NaN  1.307662
# 33   mc      85      NaN  1.092811
# 34   mc      80      NaN  0.913310
# 35   mc      75      NaN  0.751863
# 36   mc      70      NaN  0.613554
# 37   mc      65      NaN  0.494368
# 38   mc      60      NaN  0.392802
# 39   mc      55      NaN  0.299329
# 40   mc      50      NaN  0.228054
# 41   mc      45      NaN  0.165732
# 42   mc      40      NaN  0.118291
# 43   mc      35      NaN  0.079750
# 44   mc      30      NaN  0.050519
# 45   mc      25      NaN  0.029481
# 46   mc      20      NaN  0.015440
# 47   mc      15      NaN  0.006686
# 48   mc      10      NaN  0.002099
# 49   mc       5      NaN  0.000311

# %%
algo = 'fw'

plt.figure(figsize=(8, 6))
d = df[df['algo'] == algo].copy()
plt.scatter(d['main_n'], d['time'], label='Practical time')

coeffs = np.polyfit(x=d['main_n'] ** 3, y=d['time'], deg=1)
theor = coeffs[0] * d['main_n'] ** 3 + coeffs[1]
plt.plot(d['main_n'], theor, color='orange', label='Theoretical approximation')

plt.xlabel('Number of vertices', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Time, s', fontsize=16)
plt.yticks(fontsize=14)
plt.title('Floyd-Warshall algorithm time complexity', fontsize=16)
plt.legend();

# %%
algo = 'mc'

plt.figure(figsize=(8, 6))
d = df[df['algo'] == algo].copy()
plt.scatter(d['main_n'], d['time'], label='Practical time')

coeffs = np.polyfit(x=d['main_n'] ** 3, y=d['time'], deg=1)
theor = coeffs[0] * d['main_n'] ** 3 + coeffs[1]
plt.plot(d['main_n'], theor, color='orange', label='Theoretical approximation')

plt.xlabel('Number of matrices', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Time, s', fontsize=16)
plt.yticks(fontsize=14)
plt.title('Matrix chain multiplication algorithm \ntime complexity', fontsize=16)
plt.legend();
